# %% [markdown]
# # Python 基础知识

# %% [markdown]
# ### Jupyter Notebook 操作

# %% [markdown]
# 提供程序开发环境的应用程序，一般包括代码编辑器、编译器、调试器和图形用户界面等工具
#
# *Python自带：IDLE
# *常用：Pycharm ，Spyder ，Jupyter……
# **有关Jupyter

# %% [markdown]
# · 常用Cell 类型：code+markdown
# · Cell转换：可用Esc+M 将选中Cell变为Markdown，Esc+Y变为代码
# · 保存方式：File-Download as：ipynb可用于分享给其他人，html可用于展示
# · 运行及新建下一个Cell：ctrl+enter可运行当前cell，Alt+Enter可运行当前Cell并新建下一个Cell

# %% [markdown]
# #### Markdown cell

# %% [markdown]
# · 可以使用#，##，###加一个空格后输入文字，作为一级，二级，三级标题
# · 插入链接---[部分快捷键参考](https://zhidao.baidu.com/question/1800695798976401387.html)

# %% [markdown]
# #### Code Cell

# %% [markdown]
# · 可以使用#后跟文字作为代码中注释，如下:

# %%
def tanh(x): #双曲函数
    return np.tanh(x)

def tanh_deriv(x): #双曲函数导数
    return 1.0 - np.tanh(x)*np.tanh(x)
 
def logistic(x): # sigmoid 函数
    return 1/(1 + np.exp(-x))
 
def logistic_derivative(x): # sigmoid 函数导数
    return logistic(x)*(1-logistic(x))

# %% [markdown]
# · 一些快捷键：
#         Ctrl-] : 缩进
#         Ctrl-[ : 解除缩进

# %% [markdown]
# ## Python 代码特征

# %% [markdown]
# 行与缩进：
# python使用缩进来表示代码块，不需要使用大括号 {} 。缩进的空格数可变，同一个代码块的语句必须包含相同的缩进空格数
# Python 通常是一行写完一条语句，但如果语句很长，我们可以使用反斜杠(\)来实现多行语句
#
# 语句特征：
# Python经常使用英文关键字，代码较为易读

# %% [markdown]
# ### 代码块

# %%
a = 1
Suma = 0
while a <= 100:
    Suma = a + Suma
    a += 1
else:
    print('计算已完成')
print(Suma)
# Out:
# 计算已完成
# 5050

# %% [markdown]
# ### Print

# %%
n = 100
suma = 0
counter = 1
while counter <= n:
    suma = suma + counter
    counter += 1
print("1 到 %d 之和为: %d" % (n,suma))
# Out:
# 1 到 100 之和为: 5050

# %% [markdown]
# %字符：标记转换说明符的开始。
# 在%的左侧放置一个字符串（格式化字符串），而右侧则放置希望格式化的值。
# %s表示格式化规则
# %s,表示字符 %d表示整数

# %%
#print('%s is a %s student from %s'%('laoliu','good','RUC'))
mingdan = ('zheshei','bad','PKU')
print('%s is a %s student from %s'%mingdan)
# Out:
# zheshei is a bad student from PKU

# %% [markdown]
# ### Import

# %% [markdown]
# Import：用于导入模块
# 在 python 用 import 或者 from...import 来导入相应的模块。
# 将整个模块(somemodule)导入，格式为： import somemodule
# 从某个模块中导入某个函数,格式为： from somemodule import somefunction
# 从某个模块中导入多个函数,格式为： from somemodule import firstfunc, secondfunc, thirdfunc
# 将某个模块中的全部函数导入，格式为： from somemodule import *

# %% [markdown]
# ### 运算符

# %%
#算数运算符及判断运算符
#print(44+50)
#print(3**3)
print(50==50)
# Out:
# True

# %%
#赋值运算符
#a, b, c, d = 20, 5.5, True, 4+3j
#print(a,b,c,d)
#print(b)
a = 1
b = 2
a += b
print(a)
# Out:
# 3

# %%
#逻辑运算符
print(99>80 and 79>80)
print(99>80 or 79>80)
print(99==30)
# Out:
# False
# True
# False

# %% [markdown]
# ### 函数

# %%
#好坏学生分辨器
def judgesb(name,university):
    if university == 'RUC':
        print('%s is a good student'%name)
    else:
        print('%s is a bad student'%name)

#judgesb("yucheng",'RUC')
judgesb('buzhidaozheshei','THU')
# Out:
# buzhidaozheshei is a bad student

# %%
#面积计算器
def area(width, height):
    return width * height
w = 4
h = 5

print("width =", w, " height =", h, " area =", area(w, h))
# Out:
# width = 4  height = 5  area = 20

# %% [markdown]
# ### 数据类型

# %% [markdown]
# #### Number

# %% [markdown]
# 数据类型：
# 整型(Int) - 通常被称为是整型或整数，是正或负整数，不带小数点。
# 浮点型(float) - 浮点型由整数部分与小数部分组成，浮点型也可以使用科学计数法表示（2.5e2 = 2.5 x 102 = 250）
# 复数( (complex)) - 复数由实数部分和虚数部分构成，可以用a + bj,或者complex(a,b)表示， 复数的实部a和虚部b都是浮点型。
#
# 查看数据类型：type（）
#
# 数据类型转换：
# int(x) 将x转换为一个整数。
# float(x) 将x转换到一个浮点数。

# %%
#查看数据类型
a = 8
b = 9.7 #浮点
c = -2
d = 'good_night' #字符串
print(type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'int'> <class 'str'>

# %%
e = a+b
print(type(e))
# Out:
# <class 'float'>

# %%
#函数应用
print('-2的绝对值是%d'%abs(c),'a,b,c中最小的数是%d'%min(a,b,c))
# Out:
# -2的绝对值是2 a,b,c中最小的数是-2

# %% [markdown]
# #### String

# %% [markdown]
# Python 访问子字符串，可以使用方括号来截取字符串
# var1 = 'Hello World!'
# var2 = "Runoob"
#
# print ("var1[0]: ", var1[0])
# print ("var2[1:5]: ", var2[1:5])

# %%
#切片
d = 'good_night'

print(d[1:3])#第1个和第2个
print(d[0])#第0个
print(d[-1])#最后一个
# Out:
# oo
# g
# t

# %% [markdown]
# ### list列表

# %% [markdown]
# 列表中的每个元素都分配一个索引，第一个索引是0，第二个索引是1
# 列表可以进行的操作包括索引，切片，加，乘，检查成员
# 列表可以作为一个方括号内的逗号分隔值出现
# 列表的数据项不需要具有相同的类型

# %%
ucboard_list = ['laoliu','yucheng','zuowei','yuning','jiazhen']
#print('列表长度为',len(ucboard_list))
#添加元素
#print(ucboard_list.append('new'))
#print(ucboard_list)
#删除元素
print(ucboard_list.pop())
print(ucboard_list)
# Out:
# jiazhen
# ['laoliu', 'yucheng', 'zuowei', 'yuning']

# %%
#查看index
ucboard_list.index('zuowei')
# Out:
# 2

# %% [markdown]
# ### 字典

# %%
#学院key-value
dict1 = {'yucheng': 'Business', 'laoliu': 'Human Resource', 'jiazhen': 'History'}
dict1['zuowei']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-ffbb5ce7c093> in <module>
#       1 #学院key-value
#       2 dict1 = {'yucheng': 'Business', 'laoliu': 'Human Resource', 'jiazhen': 'History'}
# ----> 3 dict1['zuowei']
#
# KeyError: 'zuowei'

# %%
#!pip install jieba
# Out:
# ...
#   Running setup.py install for jieba: started
#     Running setup.py install for jieba: finished with status 'done'
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import jieba
words=jieba.lcut('王： （两军阵前，拱手）来者可是诸葛孔明？\
诸葛：（扶扇拱手）正是。\
王： 久闻公之大名，今日有幸相会！公既知天命，识时务，为何要兴无名之师？犯我\
疆界？\
诸葛：我奉诏讨贼，何谓之无名？\
王： 天数有变，神器更易，而归有德之人，此乃自然之理。（曹真在旁点头）\
诸葛：（羽扇遥指）曹贼篡汉，霸占中原，何称有德之人？\
王： 自桓帝、灵帝以来，黄巾猖獗，天下纷争，社稷有累卵之危，生灵有倒悬之急，\
我太祖武皇帝，扫清六合，席卷八荒，万姓倾心，四方仰德，此非以权势取之，实乃天\
命所归也！我世祖文皇帝，神文圣武，继承大统，应天合人，法尧禅舜，处中国以治万\
邦，这岂非天心人意乎？今公蕴大才，抱大器自比管仲，乐毅，何乃要逆天理，背人情\
而行事？岂不闻古人云：顺天者昌，逆天者亡。今我大魏带甲百万，良将千员。谅尔等腐\
草之萤光，如何比得上天空之皓月？你若倒戈卸甲，以礼来降，仍不失封侯之位，国安\
民乐，岂不美哉？\
诸葛：（狂笑数声，扶扇而答）我原以为你身为汉朝老臣，来到阵前，面对两军将士。\
必有高论，没想到竟说出如此粗鄙之语！我有一言，清诸位静听。昔日桓帝、灵帝之时\
，汉统衰落，宦官酿祸，国乱岁凶，四方扰攘。黄巾之后，董卓，李榷，郭汜等接踵而\
起。劫持汉帝，残暴生灵，因之，庙堂之上，朽木为官；殿陛之间，禽兽食禄。以至狼\
心狗肺之辈汹汹当朝，奴颜婢膝之徒纷纷秉政，以致社稷变为丘墟，苍生饱受涂炭之苦\
！值此国难之际，王司徒又有何作为？王司徒之生平，我素有所知，你世居东海之滨，\
初举孝廉入仕，理当匡君辅国，安汉兴刘，何期反助逆贼，同谋篡位！罪恶深重，天地\
不容！\
王： （手指诸葛亮）你……诸葛村夫，你敢……\
诸葛：（愤而站立）住口！无耻老贼，岂不知天下之人，皆愿生啖你肉，安敢在此饶舌\
！今幸天意不绝炎汉，昭烈皇帝于西川，继承大统，我今奉嗣君之旨，兴师讨贼，你既\
为谄谀之臣，只可潜身缩首，苟图衣食，怎敢在我军面前妄称天数！皓首匹夫？苍髯老\
贼？你即将命归九泉之下，届时有何面目去见汉朝二十四代先帝？！\
王： （手捂胸口，颤声）我、我、我……\
诸葛：（大声斥责）二臣贼子，你枉活七十有六，一生未立寸功，只会摇唇鼓舌！助曹\
为虐！一条断脊之犬，还敢在我军阵前狺狺狂吠，我从未见过有如此厚颜无耻之人！\
王： 你、你……啊……（坠于马下，左右上前扶起，已死')

# %%
words
# Out:
# ['王',
#  '：',
#  ' ',
#  '（',
#  '两军',
#  '阵前',
#  '，',
#  '拱手',
#  '）',
#  '来者',
#  '可是',
#  '诸葛孔明',
#  '？',
#  '诸葛',
#  '：',
#  '（',
#  '扶扇',
#  '拱手',
#  '）',
#  '正是',
#  '。',
#  '王',
#  '：',
#  ' ',
#  '久闻',
#  '公之',
#  '大名',
#  '，',
#  '今日',
#  '有幸',
#  '相会',
#  '！',
#  '公',
#  '既',
#  '知天命',
#  '，',
#  '识时务',
#  '，',
#  '为何',
#  '要兴',
#  '无名之师',
#  '？',
#  '犯',
#  '我',
#  '疆界',
#  '？',
#  '诸葛',
#  '：',
#  '我',
#  '奉',
#  '诏',
#  '讨贼',
#  '，',
#  '何谓',
#  '之',
#  '无名',
#  '？',
#  '王',
#  '：',
#  ' ',
#  '天数',
#  '有变',
#  '，',
#  '神器',
#  '更',
#  '易',
#  '，',
#  '而',
#  '归',
#  '有',
#  '德之人',
#  '，',
#  '此',
#  '乃',
#  '自然',
#  '之理',
#  '。',
#  '（',
#  '曹真',
#  '在',
#  '旁',
#  '点头',
#  '）',
#  '诸葛',
#  '：',
#  '（',
#  '羽扇',
#  '遥指',
#  '）',
#  '曹贼',
#  '篡汉',
#  '，',
#  '霸占',
#  '中原',
#  '，',
#  '何称',
#  '有',
#  '德之人',
#  '？',
#  '王',
#  '：',
#  ' ',
#  '自桓帝',
#  '、',
#  '灵帝',
#  '以来',
#  '，',
#  '黄巾',
#  '猖獗',
#  '，',
#  '天下',
#  '纷争',
#  '，',
#  '社稷',
#  '有',
#  '累卵之危',
#  '，',
# ...

# %%
#统计词频
def countwords(words):
    phrase={}
    for i in words:
        if i not in phrase:
            phrase[i]=1
        else:
            phrase[i]+=1

    for key,value in phrase.items():
        print(key,value)
countwords(words)
# Out:
# 王 7
# ： 14
#   7
# （ 10
# 两军 2
# 阵前 3
# ， 88
# 拱手 2
# ） 9
# 来者 1
# 可是 1
# 诸葛孔明 1
# ？ 13
# 诸葛 6
# 扶扇 2
# 正是 1
# 。 9
# 久闻 1
# 公之 1
# 大名 1
# 今日 1
# 有幸 1
# 相会 1
# ！ 13
# 公 1
# 既 2
# 知天命 1
# 识时务 1
# 为何 1
# 要兴 1
# 无名之师 1
# 犯 1
# 我 12
# 疆界 1
# 奉 1
# 诏 1
# 讨贼 2
# 何谓 1
# 之 10
# 无名 1
# 天数 2
# 有变 1
# 神器 1
# 更 1
# 易 1
# 而 4
# 归 1
# 有 7
# 德之人 2
# 此 2
# 乃 1
# 自然 1
# 之理 1
# 曹真 1
# 在 4
# 旁 1
# 点头 1
# 羽扇 1
# 遥指 1
# 曹贼 1
# 篡汉 1
# 霸占 1
# 中原 1
# 何称 1
# 自桓帝 1
# 、 5
# 灵帝 2
# 以来 1
# 黄巾 2
# 猖獗 1
# 天下 2
# 纷争 1
# 社稷 2
# 累卵之危 1
# 生灵 2
# 倒悬之急 1
# 太祖 1
# 武皇帝 1
# 扫清 1
# 六合 1
# 席卷八荒 1
# 万姓 1
# 倾心 1
# 四方 2
# 仰德 1
# 此非 1
# 以 1
# 权势 1
# 取 1
# 实乃 1
# 天命 1
# 所归 1
# 也 1
# 世祖 1
# 文 1
# 皇帝 2
# 神 1
# 文圣武 1
# 继承 2
# 大统 2
# 应天 1
# 合人 1
# 法尧禅 1
# 舜 1
# 处 1
# 中国 1
# 以治 1
# 万邦 1
# 这 1
# 岂非 1
# 天心 1
# 人意乎 1
# 今公蕴 1
# 大才 1
# 抱 1
# 大器 1
# 自比 1
# 管仲 1
# 乐毅 1
# 何乃要 1
# 逆 1
# 天理 1
# 背 1
# 人情 1
# 行事 1
# 岂不闻 1
# 古人云 1
# 顺天者昌 1
# 逆天者亡 1
# 今 1
# 大 1
# 魏带 1
# 甲 1
# 百万 1
# 良将 1
# 千员 1
# 谅尔 1
# 等 2
# 腐草 1
# 萤光 1
# 如何 1
# 比得上 1
# 天空 1
# ...
